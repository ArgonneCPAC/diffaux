# %%
import os
from diffaux.validation.read_size_validation_data import read_size_data, validation_info
from diffaux.validation.read_size_validation_data import get_author_list

# %%
authors_rm = get_author_list(validation_info['Re_vs_Mstar'])
authors_re = get_author_list(validation_info['Re_vs_z_data'])
# Out:
# authors =  ['kawinwanichakij_2021', 'mowla_2019', 'george_2024_3000', 'george_2024_5000']
# authors =  ['mowla_2019', 'kawinwanichakij_2021']

# %%
Redata = read_size_data({}, authors_re, info_key='Re_vs_z_data')
# Out:
# Reading data from /Users/kovacs/anaconda3/envs/diffaux/lib/python3.12/site-packages/diffaux/data/GalaxySizes/mowla_2019/mowla_2019_Table3_Re_vs_z_data.txt
# ..Assigning symmetric errors for dRe_med_All-
# ..Assigning symmetric errors for dRe_med_Starforming-
# ..Assigning symmetric errors for dRe_med_Quiescent-
# Reading data from /Users/kovacs/anaconda3/envs/diffaux/lib/python3.12/site-packages/diffaux/data/GalaxySizes/kawinwanichakij_2021/kawinwanichakij_Table6a_Re_median_vs_z.txt
# ..Assigning symmetric errors for dRe_med_All-
# ..Assigning symmetric errors for dRe_med_Quiescent-
# ..Assigning symmetric errors for dRe_med_Starforming-

# %%
Rmdata= read_size_data({}, authors_rm, info_key='Re_vs_Mstar')

# %%
authors = get_author_list(validation_info['Re_vs_z'])
data= read_size_data({}, authors, info_key='Re_vs_z')
# Out:
# authors =  ['martorano_2024', 'george_2024_3000', 'george_2024_5000', 'kawinwanichakij_2021', 'mowla_2019', 'vanderWel_2014']
# Reading data from /Users/kovacs/anaconda3/envs/diffaux/lib/python3.12/site-packages/diffaux/data/GalaxySizes/martorano_2024/martorano_2024_table2_Re_vs_z.txt
# Flipping sign of beta_All
# Flipping sign of beta_Starforming
# Flipping sign of beta_Quiescent
# ..Converting alpha_All from log to B_All
# ..Converting dalpha_All+ from log to dB_All+
# ..Converting alpha_Starforming from log to B_Starforming
# ..Converting dalpha_Starforming+ from log to dB_Starforming+
# ..Converting alpha_Quiescent from log to B_Quiescent
# ..Converting dalpha_Quiescent+ from log to dB_Quiescent+
# Reading data from /Users/kovacs/anaconda3/envs/diffaux/lib/python3.12/site-packages/diffaux/data/GalaxySizes/george_2024_3000/George_2024_Table3a_3000_Re_vs_z.txt
# Flipping sign of beta_Starforming
# Flipping sign of beta_Quiescent
# ..Assigning symmetric errors for dB_Starforming-
# ..Assigning symmetric errors for dbeta_Starforming-
# ..Assigning symmetric errors for dB_Quiescent-
# ..Assigning symmetric errors for dbeta_Quiescent-
# Reading data from /Users/kovacs/anaconda3/envs/diffaux/lib/python3.12/site-packages/diffaux/data/GalaxySizes/george_2024_5000/George_2024_Table3b_5000_Re_vs_z.txt
# Flipping sign of beta_Starforming
# Flipping sign of beta_Quiescent
# ..Assigning symmetric errors for dB_Starforming-
# ..Assigning symmetric errors for dbeta_Starforming-
# ..Assigning symmetric errors for dB_Quiescent-
# ..Assigning symmetric errors for dbeta_Quiescent-
# Reading data from /Users/kovacs/anaconda3/envs/diffaux/lib/python3.12/site-packages/diffaux/data/GalaxySizes/kawinwanichakij_2021/kawinwanichakij_Table6b_Re_vs_z.txt
# ..Assigning symmetric errors for dB_All-
# ..Assigning symmetric errors for dbeta_All-
# ..Assigning symmetric errors for dB_Quiescent-
# ..Assigning symmetric errors for dbeta_Quiescent-
# ..Assigning symmetric errors for dB_Starforming-
# ..Assigning symmetric errors for dbeta_Starforming-
# Reading data from /Users/kovacs/anaconda3/envs/diffaux/lib/python3.12/site-packages/diffaux/data/GalaxySizes/mowla_2019/mowla_2019_Table1b_3b_Re_vs_z.txt
# ..Assigning symmetric errors for dB_All-
# ..Assigning symmetric errors for dbeta_All-
# ..Assigning symmetric errors for dB_Starforming-
# ..Assigning symmetric errors for dbeta_Starforming-
# ..Assigning symmetric errors for dB_Quiescent-
# ..Assigning symmetric errors for dbeta_Quiescent-
# Reading data from /Users/kovacs/anaconda3/envs/diffaux/lib/python3.12/site-packages/diffaux/data/GalaxySizes/vanderWel_2014/vanderWel_2014_table2_Re_vs_z.txt
# Flipping sign of beta_Starforming
# Flipping sign of beta_Quiescent
# ..Converting alpha_Starforming from log to B_Starforming
# ..Converting dalpha_Starforming+ from log to dB_Starforming+
# ..Assigning symmetric errors for dB_Starforming-
# ..Assigning symmetric errors for dbeta_Starforming-
# ..Converting alpha_Quiescent from log to B_Quiescent
# ..Converting dalpha_Quiescent+ from log to dB_Quiescent+
# ..Assigning symmetric errors for dB_Quiescent-
# ..Assigning symmetric errors for dbeta_Quiescent-

# %%
authors_rd = get_author_list(validation_info['Re_vs_Mstar_data'])
Rddata = {}
for author in authors_rd:
    samples = validation_info['Re_vs_Mstar_data'][author]['samples']
    for sample in samples:
        if 'All' not in sample:
            Rddata = read_size_data(Rddata, authors_rd, info_key='Re_vs_Mstar_data', sample=sample)
# Out:
# authors =  ['martorano_2024']
# Reading data from /Users/kovacs/anaconda3/envs/diffaux/lib/python3.12/site-packages/diffaux/data/GalaxySizes/martorano_2024/martorano_2024_table1_Mstar_log10Re_Starforming.txt
# Processing $0.5 \leq z < 1.0$
# ..Converting log10_Re_50%_Starforming from log to Re_Starforming
# ..Converting log10_Re_84%_Starforming from log to dRe_Starforming+
# Processing $1.0 \leq z < 1.5$
# ..Converting log10_Re_50%_Starforming from log to Re_Starforming
# ..Converting log10_Re_84%_Starforming from log to dRe_Starforming+
# Processing $1.5 \leq z < 2.0$
# ..Converting log10_Re_50%_Starforming from log to Re_Starforming
# ..Converting log10_Re_84%_Starforming from log to dRe_Starforming+
# Processing $2.0 \leq z < 2.5$
# ..Converting log10_Re_50%_Starforming from log to Re_Starforming
# ..Converting log10_Re_84%_Starforming from log to dRe_Starforming+
# Reading data from /Users/kovacs/anaconda3/envs/diffaux/lib/python3.12/site-packages/diffaux/data/GalaxySizes/martorano_2024/martorano_2024_table1_Mstar_log10Re_Quiescent.txt
# Processing $0.5 \leq z < 1.0$
# ..Converting log10_Re_50%_Quiescent from log to Re_Quiescent
# ..Converting log10_Re_84%_Quiescent from log to dRe_Quiescent+
# Processing $1.0 \leq z < 1.5$
# ..Converting log10_Re_50%_Quiescent from log to Re_Quiescent
# ..Converting log10_Re_84%_Quiescent from log to dRe_Quiescent+
# Processing $1.5 \leq z < 2.0$
# ..Converting log10_Re_50%_Quiescent from log to Re_Quiescent
# ..Converting log10_Re_84%_Quiescent from log to dRe_Quiescent+
# Processing $2.0 \leq z < 2.5$
# ..Converting log10_Re_50%_Quiescent from log to Re_Quiescent
# ..Converting log10_Re_84%_Quiescent from log to dRe_Quiescent+

# %%
notebook_dir = '/Users/kovacs/cosmology/diff_notebooks'
from diffaux.validation.plot_size_data import plot_size_data
from diffaux.validation.plot_size_data import PLOT_DRN

# %%
plot_size_data(Rddata, validation_info, authors, info_keys=['Re_vs_Mstar_data'], plotdir=os.path.join(notebook_dir, PLOT_DRN))

# %%
plot_size_data(Rmdata, validation_info, authors_rm, info_keys=['Re_vs_Mstar'], summary_only=True, plotdir=os.path.join(notebook_dir, PLOT_DRN))

# %%
plot_size_data(Redata, validation_info, authors, info_keys=['Re_vs_z_data'], plotdir=os.path.join(notebook_dir, PLOT_DRN), summary_only=True)

# %%
plot_size_data(data, validation_info, authors, info_keys=['Re_vs_z'], plotdir=os.path.join(notebook_dir, PLOT_DRN), summary_only=True)
# Out:
# Saving /Users/kovacs/cosmology/diff_notebooks/./SizePlots/Re_vs_z_summary

# %%
from diffaux.size_modeling.fit_size_data import Samples_zFit
from diffaux.size_modeling.fit_size_data import zFitParams_initial
print(zFitParams_initial)
# Out:
# zFitParameters(B_Starforming=SigmoidParameters(x0=11.5, k=2.7, ymin=3.0, ymax=40.0), beta_Starforming=SigmoidParameters(x0=11.3, k=2.5, ymin=0.15, ymax=2.5), B_Quiescent=SigmoidParameters(x0=11.0, k=3.6, ymin=1.5, ymax=16.0), beta_Quiescent=SigmoidParameters(x0=10.0, k=8.0, ymin=0.4, ymax=1.2))

# %%
from diffaux.size_modeling.fit_size_data import collect_data_vectors
#authors_fit = get_author_list(validation_info['Re_vs_z'], lambda_min=0.5, lambda_max=1.0)
#data_fit = read_size_data({}, authors_fit, info_key='Re_vs_z')
data_vectors = collect_data_vectors(data, Samples_zFit, validation_info, fit_type='Re_vs_z',
                                    lambda_min=0.5, lambda_max=1.0)
# Out:
# Skipping martorano_2024 1.5
# Skipping george_2024_3000 0.3
# Processing george_2024_5000 0.5
# Processing kawinwanichakij_2021 0.5
# Processing mowla_2019 0.55
# Processing vanderWel_2014 0.5
# Skipping martorano_2024 1.5
# Skipping george_2024_3000 0.3
# Processing george_2024_5000 0.5
# Processing kawinwanichakij_2021 0.5
# Processing mowla_2019 0.55
# Processing vanderWel_2014 0.5

# %%
#print(data_vectors)
from diffaux.size_modeling.fit_size_data import assign_p0_values_to_fits
#assign initial values to fits dict and plot
fits = assign_p0_values_to_fits(zFitParams_initial, fit_type='Re_vs_z')

# %%
from diffaux.validation.plot_size_fits import plot_fits

# %%
fit_type = 'Re_vs_z'
plot_fits(fits[fit_type], data_vectors[fit_type], Samples_zFit, validation_info[fit_type], plotdir=os.path.join(notebook_dir, PLOT_DRN),
          title='_InitialGuess')

# %%
fit_type = 'Re_vs_z'
from diffaux.size_modeling.fit_size_data import fit_parameters, _sigmoid
fits = {}
from diffaux.size_modeling.fit_size_data import Xvalue_zFit
print(zFitParams_initial)
fits[fit_type] = fit_parameters(data_vectors[fit_type], Xvalue_zFit, zFitParams_initial, func=_sigmoid)
# Out:
# zFitParameters(B_Starforming=SigmoidParameters(x0=11.5, k=2.7, ymin=3.0, ymax=40.0), beta_Starforming=SigmoidParameters(x0=11.3, k=2.5, ymin=0.15, ymax=2.5), B_Quiescent=SigmoidParameters(x0=11.0, k=3.6, ymin=1.5, ymax=16.0), beta_Quiescent=SigmoidParameters(x0=10.0, k=8.0, ymin=0.4, ymax=1.2))
# Fit parameters:  B_Starforming [11.08083014  4.79598826  4.14376663 20.25107251]
# Errors:  B_Starforming [0.03549948 0.17692978 0.02636606 1.47275972]
# Fit parameters:  beta_Starforming [10.91672546 11.91362628  0.3652059   1.19675983]
# Errors:  beta_Starforming [0.01358416 2.15808867 0.0069229  0.05281388]
# Fit parameters:  B_Quiescent [11.04919805  3.44065102  1.67153891 17.0813554 ]
# Errors:  B_Quiescent [0.03179275 0.11800408 0.04167963 0.88140669]
# Fit parameters:  beta_Quiescent [10.1800515   6.00703528  0.13967383  1.28189666]
# Errors:  beta_Quiescent [0.01966224 0.47142061 0.03720733 0.0208322 ]

# %%
#print(fits)
author_list = get_author_list(validation_info['Re_vs_z'], lambda_min=0.5, lambda_max=1.0)
plot_fits(fits[fit_type], data_vectors[fit_type], Samples_zFit, validation_info[fit_type], func=_sigmoid,
          data=data[fit_type], authors=author_list, plotdir=os.path.join(notebook_dir, PLOT_DRN))

# %%
import pickle
from diffaux.size_modeling.fit_size_data import zFitParameters
from diffaux.size_modeling.fit_size_data import write_fit_parameters, read_fit_parameters

# %%
#write_fit_parameters(fits, fitdir=os.path.join(fit_dir, FIT_DRN))
write_fit_parameters(fits, fitdir='./')

# %%
#fit_pars, fits = read_fit_parameters(zFitParameters, fitdir=os.path.join(fit_dir, FIT_DRN))
fit_pars, fits = read_fit_parameters(zFitParameters)
print(fit_pars)
# Out:
# Assembling zFitParameters from fit values for parameters B_Starforming, beta_Starforming, B_Quiescent, beta_Quiescent
# zFitParameters(B_Starforming=array([11.08083014,  4.79598826,  4.14376663, 20.25107251]), beta_Starforming=array([10.91672546, 11.91362628,  0.3652059 ,  1.19675983]), B_Quiescent=array([11.04919805,  3.44065102,  1.67153891, 17.0813554 ]), beta_Quiescent=array([10.1800515 ,  6.00703528,  0.13967383,  1.28189666]))

# %%
#test sizes
import numpy as np
from diffaux.size_modeling.fit_size_data import generate_sizes, get_color_mask, _sigmoid, median_size_vs_z
fit_func=_sigmoid
size_func=median_size_vs_z
N = 5000
lM_lo = 9.0
lM_hi = 12.0
z_lo = 0.
z_hi = 3.0
log_Mstar = np.random.uniform(low=lM_lo, high=lM_hi, size=N)
redshift = np.random.uniform(low=z_lo, high=z_hi, size=N)
color_gal = np.random.uniform(low=-0.2, high=2.3, size=N)
#print(log_Mstar, redshift, color)

# %%
Re, R_med, scatter_up, scatter_down = generate_sizes(zFitParams_initial, log_Mstar, redshift, color_gal,
                                                     samples=Samples_zFit)
print(np.min(R_med), np.max(R_med))
print(np.min(Re), np.max(Re))
# Out:
# 0.5263135994591883 30.483312192747263
# 0.20281114568969572 30.480234808093407

# %%
tests = [Redata, Rddata]

# %%
# make validation plots using data for measured sizes and median sizes
from diffaux.validation.plot_size_fits import plot_generated_sizes
for test, ikey in zip(tests, ['Re_vs_z_data', 'Re_vs_Mstar_data']):
    authors = get_author_list(validation_info[ikey])
    plot_generated_sizes(Re, R_med, color_gal, log_Mstar, redshift, Samples_zFit, 
                         authors, test[ikey], validation_info[ikey],
                         plotdir=os.path.join(notebook_dir, PLOT_DRN))
# Out:
# authors =  ['mowla_2019', 'kawinwanichakij_2021']
# Saving /Users/kovacs/cosmology/diff_notebooks/./SizePlots/GalaxySizes_vs_Mstar_zbins_mowla_2019_kawinwanichakij_2021.png
# authors =  ['martorano_2024']
# ..Skipping bin $0.0 \leq z < 0.5$ for martorano_2024: no data
# ..Skipping bin $0.0 \leq z < 0.5$ for martorano_2024: no data
# ..Skipping bin $2.5 \leq z < 3.0$ for martorano_2024: no data
# ..Skipping bin $2.5 \leq z < 3.0$ for martorano_2024: no data
# Saving /Users/kovacs/cosmology/diff_notebooks/./SizePlots/GalaxySizes_vs_Mstar_zbins_martorano_2024.png

# %%
#test behavior of R_med
from diffaux.validation.plot_size_fits import plot_Re_median

# %%
plot_Re_median(fit_pars, Samples_zFit, plotdir=os.path.join(notebook_dir, PLOT_DRN))
# Out:
# Saving /Users/kovacs/cosmology/diff_notebooks/./SizePlots/Re_median_vs_Mstar_ztrends.png

# %%
#Test use facing functions
def test_generate_sizes(lM_lo = 9.0, lM_hi = 12.0, NM=6, z_lo=0., z_hi=3.0, Nz=3):
    logM = np.linspace(lM_lo, lM_hi, Nm+1)
    z = np.linspace(z_lo, z_hi, Nz+1)

    return
